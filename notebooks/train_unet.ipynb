# %% [markdown]
# # Connect with Google drive

# %%
from google.colab import drive
drive.mount("/content/drive")

# %%
from pathlib import Path
import zipfile

PROJECT = Path(
    "/content/drive/MyDrive/Welding-Defect-Detection-System"
).resolve()

# %% [markdown]
# # Unzip

# %%
zip_path   = PROJECT / "dataset" / "ripple_roi.zip"
output_dir = PROJECT / "dataset"

with zipfile.ZipFile(zip_path, "r") as z:
    z.extractall(output_dir)

print("Unzipped:", output_dir)

# %% [markdown]
# # Check Struture dataset

# %%
# !find "{PROJECT}/dataset/ripple_roi" -maxdepth 2 -type d

# %% [markdown]
# # Train model

# %%
# %cd {PROJECT}

# !python -m src.unet.train \
    --data dataset/ripple_roi \
    --pretrained checkpoints/unet_512/best.pth \
    --epochs 100 \
    --batch_size 8 \
    --img_size 512 \
    --base_channel 64 \
    --lr 0.0001 \
    --num_workers 2 \
    --save_dir checkpoints/unet_512_ver2

# %% [markdown]
# # Download model

# %%
from google.colab import files

model_path = (
    "/content/drive/MyDrive/Welding-Defect-Detection-System/"
    "checkpoints/unet_512/best.pth"
)

files.download(model_path)
